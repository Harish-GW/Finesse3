# %%
import finesse
finesse.configure(plotting=True)
le=finesse.Model()
le.parse("""
l l1 P=1 
s s0 l1.p1 md.p1 L=0
mod md midx=0.4 order=1 f=0.74e7   #modulating it far from the FSR and not allowing the second order sideband to be at Resonance
s s1 md.p2 m1.p1 L=0
m m1 R=0.85 T=0.15
s cav m1.p2 m2.p1 L=1
m m2 R=1 T=0


#ad Circulated_c m1.p2.o f=0
#ad Circulated_s1 m1.p2.o f=0.74e8
#ad Circulated_s2 m1.p2.o f=1.48e8
#ad Reflected_s1 m1.p1.o f=0.74e8
#ad Reflected_s2 m1.p1.o f=1.48e8
pd Circulated m1.p2.o
pd1 Error_i m1.p1.o f=0.74e7 phase=0  #I-phase Error
#pd1 Error_q m1.p1.o f=0.74e7 phase=90 #Q-phase Error
xaxis(l1.f,lin,-1e8,1e8,10000)
""")

# %%
out=le.run()
out.plot(separate=True)
# Out:
# {finesse.detectors.powerdetector.PowerDetector: <Figure size 576x355.968 with 1 Axes>,
#  'Circulated': <Figure size 576x355.968 with 1 Axes>,
#  finesse.detectors.powerdetector.PowerDetectorDemod1: <Figure size 576x355.968 with 1 Axes>,
#  'Error_i': <Figure size 576x355.968 with 1 Axes>}
