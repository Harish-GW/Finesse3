# %%
import finesse
fbp=finesse.Model()
finesse.configure(plotting=True)
fbp.parse(f"""
var R 0
l l1 P=1
s s0 l1.p1 m1.p1 L=0
m m1 R=R L=8.5e-6 T=1-8.5e-6-R
s cav m1.p2 m2.p1 L=10
m m2 R=0.9 T=0.1 

pd Circ m1.p2.o
xaxis(R,lin,0,1,1000)

""")
fbp.run().plot()
# Out:
# {finesse.detectors.powerdetector.PowerDetector: <Figure size 576x355.968 with 1 Axes>,
#  'Circ': <Figure size 576x355.968 with 1 Axes>}
