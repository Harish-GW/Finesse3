# %%
import finesse
import numpy as np
import matplotlib.pyplot as plt

finesse.configure(plotting=True)
prmi=finesse.Model()
prmi.parse("""
#Laser
l laser P=1
s s0 laser.p1 eom1.p1 L=1

#EOMS
mod eom1 midx=0 f=9099471 order=1
s s1 eom1.p2 eom2.p1 L=1
mod eom2 midx=0.3 f=45497355 order=1
s s2 eom2.p2 Fi.p1 L=1

#Faraday isolator
dbs Fi
s s3 Fi.p3 prmar.p1 L=0

#PRM

m prmar R=0 L=4e-5 Rc=11.009
s sprmarpr prmar.p2 PRM.p1 L=0.0737 nr=1.4496 
m PRM L=8.5e-06 T=0.03
s sPRBS PRM.p2 BS.p1 L=0

#Beam Splitter
bs BS R=0.5 L=3.75e-05 alpha=45 
s sBSAR1 BS.p3 BSAR1.p1 L=0.0687 nr=1.4496
bs BSAR1 R=5e-5 L=0 phi=-29.195
s sBSAR2 BS.p4 BSAR2.p1 L=0.0687 nr=1.4496
bs BSAR2 R=5e-5 L=0 phi=29.195


#ETMx
s michx BSAR1.p3 ETMxAR.p1 L=0
m ETMxAR R=0 L=2e-5
s sETMxARETM ETMxAR.p2 ETMx.p1 L=0.2 nr=1.4496
m ETMx L=3.75e-05 T=0.014 Rc=-1934

#ETMy
s michy BS.p2 ETMyAR.p1 L=0
m ETMyAR R=0 L=2e-5
s sETMyARETM ETMyAR.p2 ETMy.p1 L=0.2 nr=1.4496
m ETMy L=3.75e-05 T=0.014 Rc=-1934

pd AS_dc BS.p4.o
pd POP_dc PRM.p2.o
pd REFL_dc PRM.p1.o

ad AS_f0 BSAR2.p3.o f=0
ad AS_f1 BS.p4.o f=9099471
ad AS_f2 BS.p4.o f=45497355
ad POP_f0 PRM.p2.o f=0
ad POP_f1 PRM.p2.o f=9099471
ad POP_f2 PRM.p2.o f=45497355

xaxis(ETMy.phi,lin,-200,200,1000)
""")
out=prmi.run()
AS_dc=[]
AS_f0=[]
AS_f1=[]
AS_f2=[]
POP_dc=[]
REFL_dc=[]

phi=np.linspace(-200,200,1000)
for i in range(1000):
    AS_f0.append(abs(out["AS_f0"][i]))
    AS_f1.append(abs(out["AS_f1"][i]))
    AS_f2.append(abs(out["AS_f2"][i]))
    AS_dc.append(out["AS_dc"][i])
    POP_dc.append(out["POP_dc"][i])
    REFL_dc.append(out["REFL_dc"][i])
fig,plots=plt.subplots(3,2,figsize=(10,12))
plots[0,0].plot(phi,AS_dc)
plots[0,0].set_ylabel("AS_dc")
plots[1,0].plot(phi,POP_dc)
plots[1,0].set_ylabel("POP_dc")
plots[2,0].plot(phi,REFL_dc)
plots[2,0].set_ylabel("REFL_dc")
plots[2,0].set_xlabel("ITMx.phi")

plots[0,1].plot(phi,AS_f0)
plots[0,1].set_ylabel("AS_f0")
plots[1,1].plot(phi,AS_f1)
plots[1,1].set_ylabel("AS_f1")
plots[2,1].plot(phi,AS_f2)
plots[2,1].set_ylabel("AS_f2")
plots[2,1].set_xlabel("ITMx.phi")

fig.tight_layout()

# %%
prmi.michy.L=4.99
prmi.michx.L=5.01
prmi.sPRBS.L=50
prmi.parse("xaxis(PRM.phi,lin,-200,200,1000)")
out=prmi.run()

AS_f0=[]
AS_f1=[]
AS_f2=[]
POP_f0=[]
POP_f1=[]
POP_f2=[]

phi=np.linspace(-200,200,1000)
for i in range(1000):
    AS_f0.append(abs(out["AS_f0"][i]))
    AS_f1.append(abs(out["AS_f1"][i]))
    AS_f2.append(abs(out["AS_f2"][i]))
    POP_f0.append(abs(out["POP_f0"][i]))
    POP_f1.append(abs(out["POP_f1"][i]))
    POP_f2.append(abs(out["POP_f2"][i]))
# fig,plots=plt.subplots(2,2,figsize=(10,8))
# plots[0,0].semilogy(phi,POP_f0)
# plots[0,0].set_ylabel("POP_f0")
# plots[1,0].semilogy(phi,POP_f2)
# plots[1,0].set_ylabel("POP_f2")
# plots[1,0].set_xlabel("PRM.phi")

# plots[0,1].plot(phi,AS_f0)
# plots[0,1].set_ylabel("AS_f0")
# plots[1,1].plot(phi,AS_f2)
# plots[1,1].set_ylabel("AS_f2")
# plots[1,1].set_xlabel("PRM.phi")

# fig.tight_layout()    
plt.semilogy(phi,POP_f0,label="Carrier")
plt.semilogy(phi,POP_f2,label="Sideband")
plt.xlabel("PRM.phi")
plt.ylabel("Amplitude")
plt.title("Amplitude vs tuning")
plt.legend(loc="best")
import scipy
from scipy import signal
sb_peaks,_=signal.find_peaks(POP_f2,height=0.5)
print(phi[sb_peaks])
# Out:
# [-53.45345345 126.72672673]

# %%
Lambda=3E8/45497355
prmi.sPRBS.L+=Lambda*phi[sb_peaks[1]]/360
prmi.parse("xaxis(ETMy.phi,lin,-200,200,10000)")
prmi.run()
out=prmi.run()

POP_f0=[]
POP_f2=[]

phi=np.linspace(-200,200,10000)
for i in range(10000):
    POP_f0.append(abs(out["POP_f0"][i]))
    POP_f2.append(abs(out["POP_f2"][i]))
plt.semilogy(phi,POP_f0,label="Carrier")
plt.semilogy(phi,POP_f2,label="Sideband")
plt.xlabel("ETMy.phi")
plt.ylabel("Amplitude")
plt.title("Amplitude vs tuning")
plt.legend(loc="best")
print(prmi.sPRBS.L)
# Out:
# 52.321137253047034 m

# %%
def f(del_l):
    prmi.michx.L=5.01+del_l
    prmi.michy.L=4.99-del_l
    out=prmi.run()
    AS_f2=[]
    for i in range(10000):
        AS_f2.append(out["AS_f2"][i])
    return abs(max(AS_f2)-min(AS_f2))
    
from scipy.optimize import minimize_scalar
res = minimize_scalar(lambda del_l: -f(del_l), bounds = [0.0, 0.20], method='bounded')
schnupp = res.x
print(schnupp, f(schnupp))
# Out:
# 0.045537144976496566 0.12189679245140761

# %%
print(f"Optimized MichX:{prmi.michx.L.value:.4f} m")
print(f"Optimized MichY:{prmi.michy.L.value:.4f} m")
print(f"Optimized Schnupp:{prmi.michx.L.value-5:.4f} m")
print(f"Optimized PR-BS length:{prmi.sPRBS.L.value:.4f} m")
# Out:
# Optimized MichX:5.0555 m
# Optimized MichY:4.9445 m
# Optimized Schnupp:0.0555 m
# Optimized PR-BS length:52.3211 m

# %%
out=prmi.run()
POP_f0=[]
POP_f2=[]
AS_f0=[]
AS_f2=[]

phi=np.linspace(-200,200,10000)
for i in range(10000):
    POP_f0.append(abs(out["POP_f0"][i]))
    POP_f2.append(abs(out["POP_f2"][i]))
    AS_f0.append(abs(out["AS_f0"][i]))
    AS_f2.append(abs(out["AS_f2"][i]))
fig,a=plt.subplots(1,2,figsize=(10,5))
a[0].semilogy(phi,POP_f0,label="POP_Carrier")
a[0].semilogy(phi,POP_f2,label="POP_Sideband")
a[0].set_xlabel("ETMy.phi (in deg)")
a[0].set_ylabel("Amplitude (in $\sqrt{W}$)")
a[0].set_title("Amplitude vs tuning")
a[0].legend(loc="best")

a[1].semilogy(phi,AS_f0,label="AS_Carrier")
a[1].semilogy(phi,AS_f2,label="AS_Sideband")
a[1].set_xlabel("ETMy.phi (in deg)")
a[1].set_ylabel("Amplitude (in $\sqrt{W}$)")
a[1].set_title("Amplitude vs tuning")
a[1].legend(loc="best")

fig.tight_layout()
