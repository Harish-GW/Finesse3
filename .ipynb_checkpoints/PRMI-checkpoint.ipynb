# %%
import finesse
finesse.configure(plotting=True)
sm=finesse.Model()
sm.parse("""
l laser1 P=1 
s s0 laser1.p1 md.p1 L=0
mod md midx=1 order=1 f=0.375e8
s s1 md.p2 pr.p1 L=0

m pr R=0.9 T=0.1    
s PRC pr.p2 bs1.p1 L=1
bs bs1 R=0.5 T=0.5  

s Lx bs1.p3 ETMx.p1 L=1   
m ETMx R=1 T=0 phi=90        

s Ly bs1.p2 ETMy.p1 L=1
m ETMy R=1 T=0 

#ad circ_i pr.p1.i f=0
pd PRC_circ pr.p2.o
xaxis(pr.phi,lin,-180,180,1000)
""")

# %%
out=sm.run()
out.plot()
# Out:
# {finesse.detectors.powerdetector.PowerDetector: <Figure size 576x355.968 with 1 Axes>,
#  'PRC_circ': <Figure size 576x355.968 with 1 Axes>}
